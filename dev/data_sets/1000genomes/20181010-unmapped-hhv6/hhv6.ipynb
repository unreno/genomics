# %%
import pandas
import matplotlib.pyplot as plt

# %%
df = pandas.read_csv('HHV6ab-report.csv')
df.head()
# Out:
#    Subject  Gender Population Super Population rs4774 rs3087456  unmapped DNA  \
# 0  HG00096    male        GBR              EUR    0|0       1|1     2083467.0
# 1  HG00097  female        GBR              EUR    0|0       0|1     1158537.0
# 2  HG00098    male        GBR              EUR    NaN       NaN           NaN
# 3  HG00099  female        GBR              EUR    0|0       1|0     1147814.0
# 4  HG00099  female        GBR              EUR    0|0       1|0     1147814.0
#
#      total DNA                sample   total RNA         ...           \
# 0  147147056.0  HG00096.1.M_111124_6  54512330.0         ...
# 1  299852157.0  HG00097.7.M_120219_2  87882216.0         ...
# 2          NaN                   NaN         NaN         ...
# 3  248856975.0  HG00099.1.M_120209_6  42279782.0         ...
# 4  248856975.0  HG00099.5.M_120131_3  79375834.0         ...
#
#    bowtie2 HHVb/total RNA(xE7)  kallisto10 HHVb/total RNA(xE7)  \
# ...

# %%
len(df)
# Out:
# 3702

# %%
RNA = df.loc[df['sample'].notnull()]
RNA.head()
# Out:
#    Subject  Gender Population Super Population rs4774 rs3087456  unmapped DNA  \
# 0  HG00096    male        GBR              EUR    0|0       1|1     2083467.0
# 1  HG00097  female        GBR              EUR    0|0       0|1     1158537.0
# 3  HG00099  female        GBR              EUR    0|0       1|0     1147814.0
# 4  HG00099  female        GBR              EUR    0|0       1|0     1147814.0
# 5  HG00100  female        GBR              EUR    0|0       1|1    13376337.0
#
#      total DNA                sample   total RNA         ...           \
# 0  147147056.0  HG00096.1.M_111124_6  54512330.0         ...
# 1  299852157.0  HG00097.7.M_120219_2  87882216.0         ...
# 3  248856975.0  HG00099.1.M_120209_6  42279782.0         ...
# 4  248856975.0  HG00099.5.M_120131_3  79375834.0         ...
# 5  421482567.0  HG00100.2.M_111215_8  44683676.0         ...
#
#    bowtie2 HHVb/total RNA(xE7)  kallisto10 HHVb/total RNA(xE7)  \
# ...

# %%
len(RNA)
# Out:
# 666

# %%
RNA.sort_values('kallisto10 HHVa/total RNA(xE7)',ascending=False)[['sample','kallisto10 HHVa/total RNA(xE7)']].head(10)
# Out:
#                     sample  kallisto10 HHVa/total RNA(xE7)
# 2808  NA18861.4.M_120208_5                          469.22
# 101   HG00189.1.M_111124_5                            3.20
# 2539  NA12272.1.M_120209_5                            2.70
# 3505  NA20539.4.M_120208_5                            2.38
# 8     HG00103.4.M_120208_3                            2.33
# 2531  NA12156.1.M_120209_7                            2.28
# 2998  NA19099.1.M_120209_4                            2.13
# 34    HG00118.4.M_120208_5                            2.08
# 182   HG00328.1.M_120209_2                            1.92
# 116   HG00245.4.M_120208_6                            1.91

# %%
RNA.sort_values('kallisto10 HHVb/total RNA(xE7)',ascending=False)[['sample','kallisto10 HHVb/total RNA(xE7)']].head(10)
# Out:
#                     sample  kallisto10 HHVb/total RNA(xE7)
# 2808  NA18861.4.M_120208_5                          468.23
# 182   HG00328.1.M_120209_2                           46.10
# 183   HG00328.2.M_111215_4                           31.12
# 3081  NA19189.1.M_120209_8                           14.52
# 2836  NA18909.4.M_120208_8                           14.25
# 2659  NA18489.2.M_111216_1                           13.22
# 3013  NA19114.1.M_120209_8                           12.76
# 65    HG00142.4.M_120208_6                           12.13
# 3069  NA19172.1.M_120209_8                           11.75
# 3038  NA19138.1.M_120209_7                           11.59

# %%
RNA.sort_values('kallisto10 HHVa/total DNA(xE7)',ascending=False)[['sample','kallisto10 HHVa/total DNA(xE7)']].head(10)
# Out:
#                     sample  kallisto10 HHVa/total DNA(xE7)
# 73    HG00149.1.M_111124_6                          315.63
# 113   HG00242.3.M_120202_7                          314.32
# 3555  NA20792.6.M_120119_6                          308.80
# 3539  NA20769.6.M_120119_5                          265.79
# 3458  NA20502.3.M_120202_4                          247.56
# 2541  NA12273.1.M_111124_4                          212.21
# 2539  NA12272.1.M_120209_5                          196.82
# 2540  NA12272.3.M_120202_5                          196.82
# 220   HG00362.3.M_120202_2                          182.17
# 3515  NA20586.2.M_111215_7                          152.27

# %%
RNA.sort_values('kallisto10 HHVb/total DNA(xE7)',ascending=False)[['sample','kallisto10 HHVb/total DNA(xE7)']].head(10)
# Out:
#                     sample  kallisto10 HHVb/total DNA(xE7)
# 220   HG00362.3.M_120202_2                          269.39
# 116   HG00245.4.M_120208_6                          263.23
# 113   HG00242.3.M_120202_7                          166.28
# 73    HG00149.1.M_111124_6                          165.83
# 3555  NA20792.6.M_120119_6                          162.55
# 3539  NA20769.6.M_120119_5                          136.92
# 3458  NA20502.3.M_120202_4                          123.30
# 2541  NA12273.1.M_111124_4                          111.04
# 2540  NA12272.3.M_120202_5                          102.25
# 2539  NA12272.1.M_120209_5                          102.25

# %%
# For some reason, if this is in the same call as the import command, it doesn't work.
plt.rcParams["figure.figsize"] = [16.0,6.0]

# %%
plt.hist(RNA['kallisto10 HHVa/total RNA(xE7)'], bins=100)
plt.title('kallisto10 HHVa/total RNA(xE7)')
plt.show()

# %%
plt.hist(RNA['kallisto10 HHVa/total RNA(xE7)'], bins=1000)
plt.title('kallisto10 HHVa/total RNA(xE7)')
plt.show()

# %%
DNA = df.loc[df['total DNA'].notnull()]
DNA.head()
# Out:
#    Subject  Gender Population Super Population rs4774 rs3087456  unmapped DNA  \
# 0  HG00096    male        GBR              EUR    0|0       1|1     2083467.0
# 1  HG00097  female        GBR              EUR    0|0       0|1     1158537.0
# 3  HG00099  female        GBR              EUR    0|0       1|0     1147814.0
# 4  HG00099  female        GBR              EUR    0|0       1|0     1147814.0
# 5  HG00100  female        GBR              EUR    0|0       1|1    13376337.0
#
#      total DNA                sample   total RNA         ...           \
# 0  147147056.0  HG00096.1.M_111124_6  54512330.0         ...
# 1  299852157.0  HG00097.7.M_120219_2  87882216.0         ...
# 3  248856975.0  HG00099.1.M_120209_6  42279782.0         ...
# 4  248856975.0  HG00099.5.M_120131_3  79375834.0         ...
# 5  421482567.0  HG00100.2.M_111215_8  44683676.0         ...
#
#    bowtie2 HHVb/total RNA(xE7)  kallisto10 HHVb/total RNA(xE7)  \
# ...

# %%
len(DNA)
# Out:
# 2732

# %%
plt.hist(DNA['kallisto10 HHVa/total DNA(xE7)'], bins=400)
plt.title('kallisto10 HHVa/total DNA(xE7)')
plt.xlim(-10,110)
plt.ylim(0,210)
plt.show()

# %%
plt.hist(DNA['bowtie2 HHVa/total DNA(xE7)'], bins=400)
plt.title('bowtie2 HHVa/total DNA(xE7)')
plt.xlim(-10,110)
plt.ylim(0,210)
plt.show()

# %%
plt.hist(DNA['kallisto10 HHVb/total DNA(xE7)'], bins=400)
plt.title('kallisto10 HHVb/total DNA(xE7)')
plt.xlim(-10,110)
plt.ylim(0,210)
plt.show()

# %%
plt.hist(DNA['bowtie2 HHVb/total DNA(xE7)'], bins=400)
plt.title('bowtie2 HHVb/total DNA(xE7)')
plt.xlim(-10,110)
plt.ylim(0,210)
plt.show()

# %%
fig, ax = plt.subplots()

for super_pop, group in DNA.groupby('Super Population'):
    ax.plot(group.index, group['bowtie2 HHVa/total DNA(xE7)'], marker='o', linestyle='', ms=12, label=super_pop)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for super_pop, group in DNA.groupby('Super Population'):
    ax.plot(group.index, group['bowtie2 HHVb/total DNA(xE7)'], marker='o', linestyle='', ms=12, label=super_pop)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for super_pop, group in DNA.groupby('Super Population'):
    ax.plot(group.index, group['kallisto10 HHVa/total DNA(xE7)'], marker='o', linestyle='', ms=12, label=super_pop)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for super_pop, group in DNA.groupby('Super Population'):
    ax.plot(group.index, group['kallisto10 HHVb/total DNA(xE7)'], marker='o', linestyle='', ms=12, label=super_pop)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for super_pop, group in RNA.groupby('Super Population'):
    ax.plot(group.index, group['kallisto10 HHVa/total RNA(xE7)'], marker='o', linestyle='', ms=12, label=super_pop)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for super_pop, group in RNA.groupby('Super Population'):
    ax.plot(group.index, group['kallisto10 HHVb/total RNA(xE7)'], marker='o', linestyle='', ms=12, label=super_pop)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for super_pop, group in RNA.groupby('Super Population'):
    ax.plot(group.index, group['bowtie2 HHVa/total RNA(xE7)'], marker='o', linestyle='', ms=12, label=super_pop)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for super_pop, group in RNA.groupby('Super Population'):
    ax.plot(group.index, group['bowtie2 HHVb/total RNA(xE7)'], marker='o', linestyle='', ms=12, label=super_pop)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for gender, group in DNA.groupby('Gender'):
    ax.plot(group.index, group['kallisto10 HHVa/total DNA(xE7)'], marker='o', linestyle='', ms=5, label=gender)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for gender, group in RNA.groupby('Gender'):
    ax.plot(group.index, group['kallisto10 HHVa/total RNA(xE7)'], marker='o', linestyle='', ms=5, label=gender)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for super_pop, group in DNA.groupby('rs4774'):
    ax.plot(group.index, group['kallisto10 HHVa/total DNA(xE7)'], marker='o', linestyle='', ms=12, label=super_pop)

ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

for super_pop, group in DNA.groupby('rs3087456'):
    ax.plot(group.index, group['kallisto10 HHVa/total DNA(xE7)'], marker='o', linestyle='', ms=12, label=super_pop)

ax.legend()

plt.show()
